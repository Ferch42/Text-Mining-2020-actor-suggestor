# %% [markdown]
# # Topic modeling cleaning
# ## cleaning

# %%
import pandas as pd

# %%
data = pd.read_csv('movie_data_total.csv')
data = pd.read_csv('full_raw_data.csv')

# %%
data
# Out:
#       Unnamed: 0                                               cast  \
# 0              0  [{'nm0000209': [' Tim Robbins']}, {'nm0327779'...
# 1              1  [{'nm0914612': [' Emma Watson']}, {'nm0341743'...
# 2              2  [{'nm0043173': [' Rick Aviles']}, {'nm0534398'...
# 3              3  [{'nm0000295': [' Kate Beckinsale']}, {'nm0640...
# 4              4  [{'nm0257920': [' William Russell']}, {'nm0183...
# ...          ...                                                ...
# 5958        1836  [{'nm0662116': [' Cecil Parker']}, {'nm0665327...
# 5959        1839  [{'nm1869008': [' Anya Engel-Adams']}, {'nm000...
# 5960        1840  [{'nm0082848': [' Bindu']}, {'nm2061852': [' A...
# 5961        1841  [{'nm0772704': [' Kyle Schmid']}, {'nm1169619'...
# 5962        1843  [{'nm0443020': [' Christian Kay']}, {'nm001244...
#
#                                               info_json  \
# 0     {'Title': 'War of the Worlds', 'Year': '2005',...
# ...

# %%
data = data[data.summary_wiki!="['NoText']"]

# %%
data = data.drop(data[data.summary_wiki == "NoSearch"].index)

# %%
data
# Out:
#       Unnamed: 0                                               cast  \
# 0              0  [{'nm0000209': [' Tim Robbins']}, {'nm0327779'...
# 1              1  [{'nm0914612': [' Emma Watson']}, {'nm0341743'...
# 2              2  [{'nm0043173': [' Rick Aviles']}, {'nm0534398'...
# 3              3  [{'nm0000295': [' Kate Beckinsale']}, {'nm0640...
# 5              5  [{'nm0000349': [' Joan Cusack']}, {'nm0000885'...
# ...          ...                                                ...
# 5958        1836  [{'nm0662116': [' Cecil Parker']}, {'nm0665327...
# 5959        1839  [{'nm1869008': [' Anya Engel-Adams']}, {'nm000...
# 5960        1840  [{'nm0082848': [' Bindu']}, {'nm2061852': [' A...
# 5961        1841  [{'nm0772704': [' Kyle Schmid']}, {'nm1169619'...
# 5962        1843  [{'nm0443020': [' Christian Kay']}, {'nm001244...
#
#                                               info_json  \
# 0     {'Title': 'War of the Worlds', 'Year': '2005',...
# ...

# %%
# parsing the input into data structures
columns = ['summary_wiki', 'cast', 'info_json']
def text_parser(text):
    result = []
    try:
        r = eval(text)
        result = r
    except:
        result = [text]
    return result

for c in columns:
    data[c] = [text_parser(x) for x in data[c]]

# %%
#data = data.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1'])

def parse_summary(summary):
    if len(summary)==1:
        return str(summary[0])
    else:
        return ' '.join([str(s) for s in summary])
data['summary_wiki'] = data['summary_wiki'].apply(parse_summary)

# %%
data.to_csv('full_raw_data_cleaned_movie_data.csv')

# %%
data
# Out:
#       Unnamed: 0                                               cast  \
# 0              0  [{'nm0000209': [' Tim Robbins']}, {'nm0327779'...
# 1              1  [{'nm0914612': [' Emma Watson']}, {'nm0341743'...
# 2              2  [{'nm0043173': [' Rick Aviles']}, {'nm0534398'...
# 3              3  [{'nm0000295': [' Kate Beckinsale']}, {'nm0640...
# 5              5  [{'nm0000349': [' Joan Cusack']}, {'nm0000885'...
# ...          ...                                                ...
# 5958        1836  [{'nm0662116': [' Cecil Parker']}, {'nm0665327...
# 5959        1839  [{'nm1869008': [' Anya Engel-Adams']}, {'nm000...
# 5960        1840  [{'nm0082848': [' Bindu']}, {'nm2061852': [' A...
# 5961        1841  [{'nm0772704': [' Kyle Schmid']}, {'nm1169619'...
# 5962        1843  [{'nm0443020': [' Christian Kay']}, {'nm001244...
#
#                                               info_json  \
# 0     {'Title': 'War of the Worlds', 'Year': '2005',...
# ...
